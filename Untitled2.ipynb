# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(10))
plt.show()

# %%
plt.title ('TEN')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
decade = [0,1,2,3,4,5,6]
ppm = [250,265,272,260,300,320,389]
plt.plot(decade,ppm)
plt.show()

# %%
plt.plot?

# %%
plt.plot(decade,ppm,'b--')
plt.xlabel('decade')
plt.ylabel('ppm')
plt.title('co2 versus time')
plt.show()

# %%
temp = [14.1,15.5,16.3,18.1,17.3,19.1,20.2]
plt.plot(decade,ppm,'b--',decade,temp,'r*-')
plt.show()
plt.savefig('co2.pdf')
